# %%
import ipywidgets as widgets
from IPython.display import display
from ipywidgets import interact
import pandas as pd
import psycopg2 as pg
import sqlalchemy
from sqlalchemy import create_engine

# %%
cnx = 'postgresql://postgres:alunoufc@localhost/meulazer'
sqlalchemy.create_engine(cnx)
# Out:
# Engine(postgresql://postgres:***@localhost/meulazer)

# %%
con = pg.connect(host='localhost', dbname= 'meulazer', user='postgres', password= 'alunoufc')

# %% [markdown]
# # USUARIO

# %% [markdown]
# ## Campos de entrada

# %%
nome_usuario = widgets.Text(
    value = '',
    placeholder = 'Nome do usuário',
    description = 'Nome usuário:',
    disabled = False
)

cpf_us = widgets.Text(
    value='',
    placeholder='Digite seu CPF',
    description='CPF: ',
    disabled=False
)
rua_us = widgets.Text(
    value = '',
    description = 'Rua:',
    disabled = False
)

estado_us = widgets.Text(
    value = '',
    description = 'Estado:',
    disabled = False
)

cidade_us = widgets.Text(
    value = '',
    description = 'Cidade:',
    disabled = False
)

cep_us = widgets.Text(
    value = '',
    description = 'CEP:',
    disabled = False
)

email_us = widgets.Text(
    value = '',
    description = 'E-MAIL:',
    disabled = False
)

telefone_us = widgets.Text(
    value = '',
    description = 'Telefone:',
    disabled = False
)

celular_us = widgets.Text(
    value = '',
    description = 'celular:',
    disabled = False
)

pontos_us = widgets.IntText(
    value=0,
    description='pontos iniciais:',
    disabled=False
)

sexo_us = widgets.RadioButtons(
    options=['M', 'F'],
    description='Sexo:',
    disabled=False
)


data_nasc = widgets.DatePicker(
    description='Data de Nascimento:',
    disabled=False
)

flag = ''

# %% [markdown]
# ## CRUD USUARIO

# %%
#CONSULTAR

button2 = widgets.Button(description="Consultar", value='')
def on_button_clicked_query(b):
        try:        
            query = f"select * from usuario ca where ('{cpf_us.value}'='{flag}' or ca.cpf_us='{cpf_us.value}')"
            df = pd.read_sql_query(query, cnx)
            output.clear_output()
            display(cpf_us,button2, df, btn_nav_menu)   
        except:
            output.clear_output()  
            display(cpf_us,button2, btn_nav_menu)
            display("Não foi possível realizar a consulta.\n")
            
button2.on_click(on_button_clicked_query)

#NAV CONSULTAR
btn_nav_consultar_usuario = widgets.Button(description="Consultar usuario", value='')
def on_button_clicked_consultar_usuario(b):
    output.clear_output()
    display(cpf_us, button2, btn_nav_menu)

btn_nav_consultar_usuario.on_click(on_button_clicked_consultar_usuario)

#INSERIR
btn_nav_inserir_usuario = widgets.Button(description="Inserir usuario", value='')
button = widgets.Button(description="Inserir", value='')
def on_button_clicked_insert(b):
    try:
        cursor= con.cursor()
        cursor.execute("insert into usuario(nome_usuario, cpf_us, rua_us, estado_us, cidade_us, cep_us, email_us, telefone_us, celular_us, pontos_us, sexo_us, data_nasc) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)",(nome_usuario.value, cpf_us.value, rua_us.value, estado_us.value, cidade_us.value, cep_us.value, email_us.value, telefone_us.value, celular_us.value, pontos_us.value, sexo_us.value, data_nasc.value))
        cursor.query
        con.commit()
        
        df = pd.read_sql("select * from usuario", cnx)
        output.clear_output()
        display(nome_usuario, cpf_us, rua_us, estado_us, cidade_us, cep_us, email_us, telefone_us, celular_us, pontos_us, sexo_us, data_nasc, button, df, btn_nav_menu)

    except:
        cursor.execute("ROLLBACK")
        output.clear_output()        
        display(nome_usuario, cpf_us, rua_us, estado_us, cidade_us, cep_us, email_us, telefone_us, celular_us, pontos_us, sexo_us, data_nasc, button, btn_nav_menu)
        display("Não foi possível realizar a inserção. Verifique restrições.")
        
    finally:
        cursor.close()
        
button.on_click(on_button_clicked_insert)

#NAV INSERIR
btn_nav_inserir_usuario = widgets.Button(description="Inserir usuario", value='')
def on_button_clicked_inserir_usuario(b):
    output.clear_output()
    display(nome_usuario, cpf_us, rua_us, estado_us, cidade_us, cep_us, email_us, telefone_us, celular_us, pontos_us, sexo_us, data_nasc, button, btn_nav_menu)

btn_nav_inserir_usuario.on_click(on_button_clicked_inserir_usuario)
        
    
#DELETAR
btn_nav_deletar_usuario = widgets.Button(description="Deletar usuario", value='')
button3 = widgets.Button(description="Deletar", value='')
def on_button_clicked_delete(b):
    try:
        cursor= con.cursor()
        cursor.execute("delete from usuario where usuario.cpf_us=%s ", (cpf_us.value,))
        rows_deleted = cursor.rowcount
        con.commit()
        df = pd.read_sql("select * from usuario", cnx)
        output.clear_output()        
        display(cpf_us,  button3, df, btn_nav_menu)
    except:
        cursor.execute("ROLLBACK")
        output.clear_output()        
        display(cpf_us, button3, btn_nav_menu)
        display("Não foi possível realizar deletar. Verifique restrições.")
            
    finally:
        cursor.close()

button3.on_click(on_button_clicked_delete)

#NAV DELETAR
btn_nav_deletar_usuario = widgets.Button(description="deletar usuario", value='')
def on_button_clicked_deletar_usuario(b):
    output.clear_output()
    display(cpf_us,  button3, btn_nav_menu)

btn_nav_deletar_usuario.on_click(on_button_clicked_deletar_usuario)


#ATUALIZAR
button4 = widgets.Button(description="Atualizar", value='')
def on_button_clicked_update(b):
        try:        
            cursor= con.cursor()
            cursor.execute("update usuario set nome_usuario = %s where cpf_us = %s",
                        (nome_usuario.value,cpf_us.value,))
            con.commit()
            df = pd.read_sql("select * from usuario", cnx)
            output.clear_output()
            display(nome_usuario, cpf_us, button2, button4, df, btn_nav_menu)   
        except:
            output.clear_output()  
            display(nome_usuario, cpf_us, button2, button4, btn_nav_menu)
            display("Não foi possível realizar a atualização.\n")
        
button4.on_click(on_button_clicked_update)
        
#NAV ATUALIZAR
btn_nav_atualizar_usuario = widgets.Button(description="atualizar usuario", value='')
def on_button_clicked_atualizar_usuario(b):
    output.clear_output()
    display(nome_usuario, cpf_us, button4, btn_nav_menu)

btn_nav_atualizar_usuario.on_click(on_button_clicked_atualizar_usuario)

# %%
#NAV CRUD usuario
btn_nav_crud_usuario = widgets.Button(description="CRUD_usuario", value='')
def on_button_nav_crud_usuario(b):
    output.clear_output()
    display(btn_nav_consultar_usuario, btn_nav_inserir_usuario, btn_nav_deletar_usuario, btn_nav_atualizar_usuario, btn_nav_menu)
    
btn_nav_crud_usuario.on_click(on_button_nav_crud_usuario)

# %% [markdown]
# # PROMOTOR

# %%
nome_promotor = widgets.Text(
    value = '',
    placeholder = 'Nome do promotor',
    description = 'Nome promotor:',
    disabled = False
)

id_usuario_fk= widgets.IntText(
    value=0,
    description='ID DE USUÁRIO:',
    disabled=False
)

cnpj= widgets.Text(
    value='',
    description='CNPJ:',
    disabled=False
)
pontos_prom = widgets.IntText(
    value=0,
    description='pontos:',
    disabled=False
)

# %%
#CONSULTAR_PROMOTOR

button_consultar_promotor = widgets.Button(description="Consultar promotor", value='')
def on_button_clicked_query_promotor(b):
        try:        
            query = f"select * from promotor ca where ('{cnpj.value}'='{flag}' or ca.cnpj='{cnpj.value}')"
            df = pd.read_sql_query(query, cnx)
            output.clear_output()
            display(cnpj, button_consultar_promotor, df, btn_nav_menu)   
        except:
            output.clear_output()  
            display(cnpj, button_consultar_promotor, btn_nav_menu)
            display("Não foi possível realizar a consulta.\n")
            
button_consultar_promotor.on_click(on_button_clicked_query_promotor)

#NAV CONSULTAR
btn_nav_consultar_promotor = widgets.Button(description="Consultar promotor", value='')
def on_button_clicked_consultar_promotor(b):
    output.clear_output()
    display(cnpj, button_consultar_promotor, btn_nav_menu)

btn_nav_consultar_promotor.on_click(on_button_clicked_consultar_promotor)

#INSERIR
button_inserir_promotor = widgets.Button(description="Inserir", value='')
def on_button_clicked_insert_promotor(b):
    try:
        cursor= con.cursor()
        cursor.execute("insert into promotor(nome_promotor, id_usuario_fk, cnpj, pontos_prom) VALUES (%s, %s, %s, %s)\n",(nome_promotor.value, id_usuario_fk.value, cnpj.value, pontos_prom.value,))
        cursor.query
        con.commit()
        
        df = pd.read_sql("select * from promotor", cnx)
        output.clear_output()
        display(nome_promotor, id_usuario_fk, cnpj, pontos_prom, button_inserir_promotor, df, btn_nav_menu)

    except:
        cursor.execute("ROLLBACK")
        output.clear_output()        
        display(nome_promotor, id_usuario_fk, cnpj, pontos_prom, button_inserir_promotor, btn_nav_menu)
        display("Não foi possível realizar a inserção. Verifique restrições.")
        
    finally:
        cursor.close()
        
button_inserir_promotor.on_click(on_button_clicked_insert_promotor)

#NAV INSERIR
btn_nav_inserir_promotor = widgets.Button(description="Inserir promotor", value='')
def on_button_clicked_inserir_promotor(b):
    output.clear_output()
    display(nome_promotor, id_usuario_fk, cnpj, pontos_prom, button_inserir_promotor, btn_nav_menu)

btn_nav_inserir_promotor.on_click(on_button_clicked_inserir_promotor)
        
    
#DELETAR
button_deletar_promotor = widgets.Button(description="Deletar", value='')
def on_button_clicked_delete_promotor(b):
    try:
        cursor= con.cursor()
        cursor.execute("delete from promotor ca where ca.cnpj=%s ", (cnpj.value, ))
        rows_deleted = cursor.rowcount
        con.commit()
        df = pd.read_sql("select * from promotor", cnx)
        output.clear_output()        
        display(cnpj,  button_deletar_promotor, df, btn_nav_menu)
    except:
        cursor.execute("ROLLBACK")
        output.clear_output()        
        display(cnpj,  button_deletar_promotor, btn_nav_menu)
        display("Não foi possível realizar deletar. Verifique restrições.")
            
    finally:
        cursor.close()

button_deletar_promotor.on_click(on_button_clicked_delete_promotor)

#NAV DELETAR
btn_nav_deletar_promotor = widgets.Button(description="Deletar promotor", value='')
def on_button_clicked_deletar_promotor(b):
    output.clear_output()
    display(cnpj, button_deletar_promotor, btn_nav_menu)

btn_nav_deletar_promotor.on_click(on_button_clicked_deletar_promotor)


#ATUALIZAR
button_atualizar_promotor = widgets.Button(description="Atualizar", value='')
def on_button_clicked_update_promotor(b):
        try:        
            cursor= con.cursor()
            cursor.execute("update promotor set nome_promotor = %s where cnpj = %s",
                        (nome_promotor.value, cnpj.value,))
            con.commit()
            df = pd.read_sql("select * from promotor", cnx)
            output.clear_output()
            display(nome_promotor, cnpj, button_consultar_promotor, button_atualizar_promotor, df, btn_nav_menu)   
        except:
            output.clear_output()  
            display(nome_promotor, cnpj, button_consultar_promotor, button_atualizar_promotor, btn_nav_menu)
            display("Não foi possível realizar a atualização.\n")
        
button_atualizar_promotor.on_click(on_button_clicked_update_promotor)
        
#NAV ATUALIZAR
btn_nav_atualizar_promotor = widgets.Button(description="atualizar promotor", value='')
def on_button_clicked_atualizar_promotor(b):
    output.clear_output()
    display(nome_promotor, cnpj, button_atualizar_promotor, btn_nav_menu)

btn_nav_atualizar_promotor.on_click(on_button_clicked_atualizar_promotor)

# %%
#NAV CRUD promotor
btn_nav_crud_promotor = widgets.Button(description="CRUD_promotor", value='')
def on_button_nav_crud_promotor(b):
    output.clear_output()
    display(btn_nav_consultar_promotor, btn_nav_inserir_promotor, btn_nav_deletar_promotor, btn_nav_atualizar_promotor, btn_nav_menu)
    
btn_nav_crud_promotor.on_click(on_button_nav_crud_promotor)

# %% [markdown]
# # EVENTO

# %%
nome_evento = widgets.Text(
    value = '',
    placeholder = 'Nome evento',
    description = 'Nome evento:',
    disabled = False
)



descricao_evento = widgets.Text(
    value = '',
    description = 'Descricao:',
    disabled = False
)


data_inicio_evento = widgets.DatePicker(
    description='Data de inicio:',
    disabled=False
)
data_fim_evento = widgets.DatePicker(
    description='Data de fim:',
    disabled=False
)

id_evento = widgets.Text(
    value = '',
    description = 'id evento:',
    disabled = False
)

# %%
#CONSULTAR_EVENTO

button_consultar_evento = widgets.Button(description="Consultar evento", value='')
def on_button_clicked_query_evento(b):
        try:        
            query = f"select * from evento ca where ('{nome_evento.value}'='{flag}' or ca.nome_evento='{nome_evento.value}')"
            df = pd.read_sql_query(query, cnx)
            output.clear_output()
            display(nome_evento, button_consultar_evento, df, btn_nav_menu)   
        except:
            output.clear_output()  
            display(nome_evento, button_consultar_evento, btn_nav_menu)
            display("Não foi possível realizar a consulta.\n")
            
button_consultar_evento.on_click(on_button_clicked_query_evento)

#NAV CONSULTAR
btn_nav_consultar_evento = widgets.Button(description="Consultar evento", value='')
def on_button_clicked_consultar_evento(b):
    output.clear_output()
    display(nome_evento, button_consultar_evento, btn_nav_menu)

btn_nav_consultar_evento.on_click(on_button_clicked_consultar_evento)

#INSERIR Evento
button_inserir_evento = widgets.Button(description="Inserir", value='')
def on_button_clicked_insert_evento(b):
    try:
        cursor= con.cursor()
        cursor.execute("insert into evento(nome_evento, descricao_evento, data_inicio_evento, data_fim_evento) VALUES (%s, %s, %s, %s)\n",(nome_evento.value, descricao_evento.value, data_inicio_evento.value, data_fim_evento.value,))
        cursor.query
        con.commit()
        
        df = pd.read_sql("select * from evento", cnx)
        output.clear_output()
        display(nome_evento, descricao_evento, data_inicio_evento, data_fim_evento, button_inserir_evento, df, btn_nav_menu)

    except:
        cursor.execute("ROLLBACK")
        output.clear_output()        
        display(nome_evento, descricao_evento, data_inicio_evento, data_fim_evento, button_inserir_evento, btn_nav_menu)
        display("Não foi possível realizar a inserção. Verifique restrições.")
        
    finally:
        cursor.close()
        
button_inserir_evento.on_click(on_button_clicked_insert_evento)

#NAV INSERIR
btn_nav_inserir_evento = widgets.Button(description="Inserir evento", value='')
def on_button_clicked_inserir_evento(b):
    output.clear_output()
    display(nome_evento, descricao_evento, data_inicio_evento, data_fim_evento, button_inserir_evento, btn_nav_menu)

btn_nav_inserir_evento.on_click(on_button_clicked_inserir_evento)


#DELETAR
button_deletar_evento = widgets.Button(description="Deletar", value='')
def on_button_clicked_delete_evento(b):
    try:
        cursor= con.cursor()
        cursor.execute("delete from evento ca where ca.nome_evento=%s ", (nome_evento.value, ))
        rows_deleted = cursor.rowcount
        con.commit()
        df = pd.read_sql("select * from evento", cnx)
        output.clear_output()        
        display(nome_evento,  button_deletar_evento, df, btn_nav_menu)
    except:
        cursor.execute("ROLLBACK")
        output.clear_output()        
        display(nome_evento,  button_deletar_evento, btn_nav_menu)
        display("Não foi possível realizar deletar. Verifique restrições.")
            
    finally:
        cursor.close()

button_deletar_evento.on_click(on_button_clicked_delete_evento)

#NAV DELETAR
btn_nav_deletar_evento = widgets.Button(description="Deletar evento", value='')
def on_button_clicked_deletar_evento(b):
    output.clear_output()
    display(nome_evento, button_deletar_evento, btn_nav_menu)

btn_nav_deletar_evento.on_click(on_button_clicked_deletar_evento)

#ATUALIZAR
button_atualizar_evento = widgets.Button(description="Atualizar", value='')
def on_button_clicked_update_evento(b):
        try:        
            cursor= con.cursor()
            cursor.execute("update evento set nome_evento = %s where id_evento = %s",
                        (nome_evento.value, id_evento.value,))
            con.commit()
            df = pd.read_sql("select * from evento", cnx)
            output.clear_output()
            display(nome_evento, id_evento, button_consultar_evento, button_atualizar_evento, df, btn_nav_menu)   
        except:
            output.clear_output()  
            display(nome_evento, id_evento, button_consultar_evento, button_atualizar_evento, btn_nav_menu)
            display("Não foi possível realizar a atualização.\n")
        
button_atualizar_evento.on_click(on_button_clicked_update_evento)
        
#NAV ATUALIZAR
btn_nav_atualizar_evento = widgets.Button(description="atualizar evento", value='')
def on_button_clicked_atualizar_evento(b):
    output.clear_output()
    display(nome_evento, id_evento, button_atualizar_evento, btn_nav_menu)

btn_nav_atualizar_evento.on_click(on_button_clicked_atualizar_evento)

# %%
#NAV CRUD evento
btn_nav_crud_evento = widgets.Button(description="CRUD_evento", value='')
def on_button_nav_crud_evento(b):
    output.clear_output()
    display(btn_nav_consultar_evento, btn_nav_inserir_evento, btn_nav_deletar_evento, btn_nav_atualizar_evento, btn_nav_menu)
#, , btn_nav_atualizar_evento,
btn_nav_crud_evento.on_click(on_button_nav_crud_evento)

# %% [markdown]
# # ATIVIDADE

# %%
nome_atv = widgets.Text(
    value = '',
    placeholder = 'Nome evento',
    description = 'Nome evento:',
    disabled = False
)
tipo_atv =widgets.RadioButtons(
    options=['ESPORTE', 'GINCANA','MULTIRAO','ATO SOLIDARIO', 'OUTRO'],
    description='TIPO:',
    disabled=False
)
data_atv = widgets.DatePicker(
    description='Data:',
    disabled=False
)
horario_atv= widgets.Text(
    placeholder = '00:00',
    description='Horario:',
    disabled=False
)

rua_atv = widgets.Text(
    value = '',
    description = 'Rua:',
    disabled = False
)

estado_atv = widgets.Text(
    value = '',
    description = 'Estado:',
    disabled = False
)

cidade_atv= widgets.Text(
    value = '',
    description = 'Cidade:',
    disabled = False
)

descricao_atv = widgets.Text(
    value = '',
    description = 'Descricao:',
    disabled = False
)

id_atividade = widgets.Text(
    value = '',
    description = 'id atividade:',
    disabled = False
)

# %%
#CONSULTAR_atividade

button_consultar_atividade = widgets.Button(description="Consultar atividade", value='')
def on_button_clicked_query_atividade(b):
        try:        
            query = f"select * from atividade ca where ('{nome_atv.value}'='{flag}' or ca.nome_atv='{nome_atv.value}')"
            df = pd.read_sql_query(query, cnx)
            output.clear_output()
            display(nome_atv, button_consultar_atividade, df, btn_nav_menu)   
        except:
            output.clear_output()  
            display(nome_atv, button_consultar_atividade, btn_nav_menu)
            display("Não foi possível realizar a consulta.\n")
            
button_consultar_atividade.on_click(on_button_clicked_query_atividade)

#NAV CONSULTAR
btn_nav_consultar_atividade = widgets.Button(description=" Consultar atividade", value='')
def on_button_clicked_consultar_atividade(b):
    output.clear_output()
    display(nome_atv, button_consultar_atividade, btn_nav_menu)

btn_nav_consultar_atividade.on_click(on_button_clicked_consultar_atividade)

#INSERIR atividade
button_inserir_atividade = widgets.Button(description="Inserir", value='')
def on_button_clicked_insert_atividade(b):
    try:
        cursor= con.cursor()
        cursor.execute("insert into atividade(nome_atv, tipo_atv, data_atv, horario_atv,rua_atv,estado_atv,cidade_atv,descricao_atv) VALUES (%s, %s, %s, %s, %s, %s, %s, %s)\n",(nome_atv.value, tipo_atv.value, data_atv.value, horario_atv.value,rua_atv.value,estado_atv.value,cidade_atv.value,descricao_atv.value,))
        cursor.query
        con.commit()
        
        df = pd.read_sql("select * from atividade", cnx)
        output.clear_output()
        display(nome_atv, tipo_atv, data_atv, horario_atv,rua_atv,estado_atv,cidade_atv,descricao_atv, button_inserir_atividade, df, btn_nav_menu)

    except:
        cursor.execute("ROLLBACK")
        output.clear_output()        
        display(nome_atv, tipo_atv, data_atv, horario_atv,rua_atv,estado_atv,cidade_atv,descricao_atv, button_inserir_atividade, btn_nav_menu)
        display("Não foi possível realizar a inserção. Verifique restrições.")
        
    finally:
        cursor.close()
        
button_inserir_atividade.on_click(on_button_clicked_insert_atividade)

#NAV INSERIR
btn_nav_inserir_atividade = widgets.Button(description="Inserir atividade", value='')
def on_button_clicked_inserir_atividade(b):
    output.clear_output()
    display(nome_atv, tipo_atv, data_atv, horario_atv,rua_atv,estado_atv,cidade_atv,descricao_atv, button_inserir_atividade, button_inserir_atividade, btn_nav_menu)

btn_nav_inserir_atividade.on_click(on_button_clicked_inserir_atividade)

#DELETAR
button_deletar_atividade = widgets.Button(description="Deletar", value='')
def on_button_clicked_delete_atividade(b):
    try:
        cursor= con.cursor()
        cursor.execute("delete from atividade ca where ca.id_atividade=%s ", (id_atividade.value, ))
        rows_deleted = cursor.rowcount
        con.commit()
        df = pd.read_sql("select * from atividade", cnx)
        output.clear_output()        
        display(id_atividade,  button_deletar_atividade, df, btn_nav_menu)
    except:
        cursor.execute("ROLLBACK")
        output.clear_output()        
        display(id_atividade,  button_deletar_atividade, btn_nav_menu)
        display("Não foi possível realizar deletar. Verifique restrições.")
            
    finally:
        cursor.close()

button_deletar_atividade.on_click(on_button_clicked_delete_atividade)

#NAV DELETAR
btn_nav_deletar_atividade = widgets.Button(description="Deletar atividade", value='')
def on_button_clicked_deletar_atividade(b):
    output.clear_output()
    display(id_atividade,  button_deletar_atividade, btn_nav_menu)

btn_nav_deletar_atividade.on_click(on_button_clicked_deletar_atividade)


#ATUALIZAR
button_atualizar_atividade = widgets.Button(description="Atualizar", value='')
def on_button_clicked_update_atividade(b):
        try:        
            cursor= con.cursor()
            cursor.execute("update atividade set nome_atv = %s where id_atividade = %s",
                        (nome_atv.value, id_atividade.value,))
            con.commit()
            df = pd.read_sql("select * from atividade", cnx)
            output.clear_output()
            display(nome_atv, id_atividade, button_consultar_atividade, button_atualizar_atividade, df, btn_nav_menu)   
        except:
            output.clear_output()  
            display(nome_atv, id_atividade, button_consultar_atividade, button_atualizar_atividade, btn_nav_menu)
            display("Não foi possível realizar a atualização.\n")
        
button_atualizar_atividade.on_click(on_button_clicked_update_atividade)
        
#NAV ATUALIZAR
btn_nav_atualizar_atividade = widgets.Button(description="atualizar atividade", value='')
def on_button_clicked_atualizar_atividade(b):
    output.clear_output()
    display(nome_atv, id_atividade, button_atualizar_atividade, btn_nav_menu)

btn_nav_atualizar_atividade.on_click(on_button_clicked_atualizar_atividade)

# %%
#NAV CRUD atividade
btn_nav_crud_atividade = widgets.Button(description="CRUD_atividade", value='')
def on_button_nav_crud_atividade(b):
    output.clear_output()
    display(btn_nav_consultar_atividade, btn_nav_inserir_atividade, btn_nav_deletar_atividade, btn_nav_atualizar_atividade, btn_nav_menu)
# btn_nav_inserir_atividade, btn_nav_deletar_atividade, btn_nav_atualizar_atividade,
btn_nav_crud_atividade.on_click(on_button_nav_crud_atividade)

# %% [markdown]
# # Quantos eventos de lazer existem na minha cidade?

# %%
# input da cidade em string
cidade_c1= widgets.Text(
    value = '',
    description = 'Cidade:',
    disabled = False
)
# Botao que ativa a consulta no banco
button_consultar_numero_eventos = widgets.Button(description="Consultar eventos na minha cidade", value='')
# Funcao que realiza a consulta
def on_button_clicked_query_c1(b):
        try:  
            # consulta
            query = f"select cidade_atv as cidade, estado_atv as estado, descricao_atv as evento, data_atv as dia, rua_atv as rua from atividade a where a.cidade_atv='{cidade_c1.value}'"
            # consulta do banco sendo colocada em df
            df = pd.read_sql_query(query, cnx)
            # limapando a saida
            output.clear_output()
            # display mostrando o campo de cidade, o botão da consulta, o resultado da consulta que está em df(em forma de tabeala), e o botão do menu
            display(cidade_c1, button_consultar_numero_eventos, df,btn_nav_menu)  
            
            # caso a consulta acima não dê certo
        except:
            # limpa a saida
            output.clear_output() 
            # display mostra o campo de cidade, botão da consulta e o botao de menu
            display(cidade_c1, button_consultar_numero_eventos, btn_nav_menu)
            # mensagem de alerta
            display("Não foi possível realizar a consulta.# Quantas organizações realizam eventos de lazer ativamente por cidade? >>>>>")

# função ".on_click" que diz ao botao qual funcao ele vai ativar quando for clicado
button_consultar_numero_eventos.on_click(on_button_clicked_query_c1)

# NAV CONSULTAR
# Parte de navegação

# Botao que aparece no menu. Se voce for na parte de menu 
# vai ver que ele está dentro de btn_nav_menu(pra quando menu for chamado ele estar visivel), 
# mas também está em dentro do display de "output" no final do codigo(para quando o codigo for iniciado pela primeira vez ele ficar visivel)
btn_nav_consultar_numero_eventos = widgets.Button(description=" 3.1 eventos por cidade", value='')

# função que faz a troca do "menu" para dentro da pagina de "consultar eventos na cidade"
def on_button_clicked_consultar_eventos_cidade(b):
    # limpando a saida
    output.clear_output()
    # mostrando o campo de cidade, o botao de consultar e menu
    display(cidade_c1,button_consultar_numero_eventos, btn_nav_menu)

# "ao clicar no botao btn_nav_consultar_numero_eventos 
# realizar a funcao on_button_clicked_consultar_eventos_cidade
# que mostra a tela de consultar eventos pela cidade
btn_nav_consultar_numero_eventos.on_click(on_button_clicked_consultar_eventos_cidade)

# %%
# Quantas organizações realizam eventos de lazer ativamente por cidade? consulta 3.2
cidade_c3= widgets.Text(
    value = '',
    description = 'Cidade:',
    disabled = False
)
# Botao que ativa a consulta no banco
button_consultar_numero_orgs_cidade = widgets.Button(description="Consultar orgs na minha cidade", value='')
# Funcao que realiza a consulta
def on_button_clicked_query_c3(b):
        try:  
            # consulta
            query = f"select * from eventos_por_cidade where cidade_atv = '{cidade_c3.value}'"
            # consulta do banco sendo colocada em df
            df = pd.read_sql_query(query, cnx)
            # limapando a saida
            output.clear_output()
            # display mostrando o campo de cidade, o botão da consulta, o resultado da consulta que está em df(em forma de tabeala), e o botão do menu
            display(cidade_c1, button_consultar_numero_orgs_cidade, df,btn_nav_menu)  
            
            # caso a consulta acima não dê certo
        except:
            # limpa a saida
            output.clear_output() 
            # display mostra o campo de cidade, botão da consulta e o botao de menu
            display(cidade_c1, button_consultar_numero_eventos, btn_nav_menu)
            # mensagem de alerta
            display("Não foi possível realizar a consulta.")

# função ".on_click" que diz ao botao qual funcao ele vai ativar quando for clicado
button_consultar_numero_orgs_cidade.on_click(on_button_clicked_query_c3)

# NAV CONSULTAR
# Parte de navegação

# Botao que aparece no menu. Se voce for na parte de menu 
# vai ver que ele está dentro de btn_nav_menu(pra quando menu for chamado ele estar visivel), 
# mas também está em dentro do display de "output" no final do codigo(para quando o codigo for iniciado pela primeira vez ele ficar visivel)
btn_nav_consultar_numero_orgs_cidade = widgets.Button(description=" 3.2 orgs por cidade", value='')

# função que faz a troca do "menu" para dentro da pagina de "consultar eventos na cidade"
def on_button_clicked_consultar_numero_orgs_cidade(b):
    # limpando a saida
    output.clear_output()
    # mostrando o campo de cidade, o botao de consultar e menu
    display(cidade_c3,button_consultar_numero_orgs_cidade, btn_nav_menu)

# "ao clicar no botao btn_nav_consultar_numero_eventos 
# realizar a funcao on_button_clicked_consultar_eventos_cidade
# que mostra a tela de consultar eventos pela cidade
btn_nav_consultar_numero_orgs_cidade.on_click(on_button_clicked_consultar_numero_orgs_cidade)

# %%
# Que tipos de atividade de lazer são realizados na minha cidade e quantos? 3.5

cidade_c35= widgets.Text(
    value = '',
    description = 'Cidade:',
    disabled = False
)
# Botao que ativa a consulta no banco
button_consultar_tipo_atividade = widgets.Button(description="Consultar tipos de atividades na minha cidade", value='')
# Funcao que realiza a consulta
def on_button_clicked_query_c35(b):
        try:  
            # consulta
            query = f"select * from tipo_atividade_cidade where cidade_atv = '{cidade_c35.value}'"
            # consulta do banco sendo colocada em df
            df = pd.read_sql_query(query, cnx)
            # limapando a saida
            output.clear_output()
            # display mostrando o campo de cidade, o botão da consulta, o resultado da consulta que está em df(em forma de tabeala), e o botão do menu
            display(cidade_c35, button_consultar_numero_orgs_cidade, df,btn_nav_menu)  
            
            # caso a consulta acima não dê certo
        except:
            # limpa a saida
            output.clear_output() 
            # display mostra o campo de cidade, botão da consulta e o botao de menu
            display(cidade_c35, button_consultar_numero_eventos, btn_nav_menu)
            # mensagem de alerta
            display("Não foi possível realizar a consulta.")

# função ".on_click" que diz ao botao qual funcao ele vai ativar quando for clicado
button_consultar_tipo_atividade.on_click(on_button_clicked_query_c35)

# NAV CONSULTAR
# Parte de navegação

# Botao que aparece no menu. Se voce for na parte de menu 
# vai ver que ele está dentro de btn_nav_menu(pra quando menu for chamado ele estar visivel), 
# mas também está em dentro do display de "output" no final do codigo(para quando o codigo for iniciado pela primeira vez ele ficar visivel)
btn_nav_consultar_tipo_atividade = widgets.Button(description="3.5 tipo de atv por cidade", value='')

# função que faz a troca do "menu" para dentro da pagina de "consultar eventos na cidade"
def on_button_clicked_consultar_tipo_atividade(b):
    # limpando a saida
    output.clear_output()
    # mostrando o campo de cidade, o botao de consultar e menu
    display(cidade_c35,button_consultar_tipo_atividade, btn_nav_menu)

# "ao clicar no botao btn_nav_consultar_numero_eventos 
# realizar a funcao on_button_clicked_consultar_eventos_cidade
# que mostra a tela de consultar eventos pela cidade
btn_nav_consultar_tipo_atividade.on_click(on_button_clicked_consultar_numero_orgs_cidade)

# %%
#Quem está realizando o evento desse patrocinador? c3.6

patro_p36= widgets.Text(
    value = '',
    description = 'patrocinador:',
    disabled = False
)
# Botao que ativa a consulta no banco
button_consultar_user_patro = widgets.Button(description="Consultar patrocinador ", value='')
# Funcao que realiza a consulta
def on_button_clicked_query_c36(b):
        try:  
            # consulta
            query = f"SELECT * FROM organizador_patrocinador where nome_patro = '{patro_p36.value}'"
            # consulta do banco sendo colocada em df
            df = pd.read_sql_query(query, cnx)
            # limapando a saida
            output.clear_output()
            # display mostrando o campo de cidade, o botão da consulta, o resultado da consulta que está em df(em forma de tabeala), e o botão do menu
            display(patro_p36, button_consultar_user_patro, df,btn_nav_menu)  
            
            # caso a consulta acima não dê certo
        except:
            # limpa a saida
            output.clear_output() 
            # display mostra o campo de cidade, botão da consulta e o botao de menu
            display(cidade_c35, button_consultar_numero_eventos, btn_nav_menu)
            # mensagem de alerta
            display("Não foi possível realizar a consulta.")

# função ".on_click" que diz ao botao qual funcao ele vai ativar quando for clicado
button_consultar_user_patro.on_click(on_button_clicked_query_c36)

# NAV CONSULTAR
# Parte de navegação

# Botao que aparece no menu. Se voce for na parte de menu 
# vai ver que ele está dentro de btn_nav_menu(pra quando menu for chamado ele estar visivel), 
# mas também está em dentro do display de "output" no final do codigo(para quando o codigo for iniciado pela primeira vez ele ficar visivel)
btn_nav_consultar_user_patro = widgets.Button(description=" 3.6 usuário que realizando evento desse patrocinador", value='')

# função que faz a troca do "menu" para dentro da pagina de "consultar eventos na cidade"
def on_button_clicked_consultar_user_patro(b):
    # limpando a saida
    output.clear_output()
    # mostrando o campo de cidade, o botao de consultar e menu
    display(patro_p36,button_consultar_user_patro, btn_nav_menu)

# "ao clicar no botao btn_nav_consultar_numero_eventos 
# realizar a funcao on_button_clicked_consultar_eventos_cidade
# que mostra a tela de consultar eventos pela cidade
btn_nav_consultar_user_patro.on_click(on_button_clicked_consultar_user_patro)

# %%
#Quais os eventos que esse usuario está promovendo e qual seu promotor? C3.7

user_u37= widgets.Text(
    value = '',
    description = 'usuário:',
    disabled = False
)
# Botao que ativa a consulta no banco
button_consultar_user = widgets.Button(description="Consultar usuário ", value='')
# Funcao que realiza a consulta
def on_button_clicked_query_c37(b):
        try:  
            # consulta
            query = f"select * from usuario_promotor_evento where nome_usuario = '{user_u37.value}'"
            # consulta do banco sendo colocada em df
            df = pd.read_sql_query(query, cnx)
            # limapando a saida
            output.clear_output()
            # display mostrando o campo de cidade, o botão da consulta, o resultado da consulta que está em df(em forma de tabeala), e o botão do menu
            display(patro_p36, button_consultar_user_patro, df,btn_nav_menu)  
            
            # caso a consulta acima não dê certo
        except:
            # limpa a saida
            output.clear_output() 
            # display mostra o campo de cidade, botão da consulta e o botao de menu
            display(user_u37, button_consultar_user, btn_nav_menu)
            # mensagem de alerta
            display("Não foi possível realizar a consulta.")

# função ".on_click" que diz ao botao qual funcao ele vai ativar quando for clicado
button_consultar_user.on_click(on_button_clicked_query_c37)

# NAV CONSULTAR
# Parte de navegação

# Botao que aparece no menu. Se voce for na parte de menu 
# vai ver que ele está dentro de btn_nav_menu(pra quando menu for chamado ele estar visivel), 
# mas também está em dentro do display de "output" no final do codigo(para quando o codigo for iniciado pela primeira vez ele ficar visivel)
btn_nav_consultar_user = widgets.Button(description=" 3.7 Consultar usuário ", value='')

# função que faz a troca do "menu" para dentro da pagina de "consultar eventos na cidade"
def on_button_clicked_consultar_user(b):
    # limpando a saida
    output.clear_output()
    # mostrando o campo de cidade, o botao de consultar e menu
    display(user_u37,button_consultar_user, btn_nav_menu)

# "ao clicar no botao btn_nav_consultar_numero_eventos 
# realizar a funcao on_button_clicked_consultar_eventos_cidade
# que mostra a tela de consultar eventos pela cidade
btn_nav_consultar_user.on_click(on_button_clicked_consultar_user)

# %%
#Qual a média de gastos desse promotor por evento? c3.8


promo_p38= widgets.Text(
    value = '',
    description = 'promotor:',
    disabled = False
)
# Botao que ativa a consulta no banco
button_consultar_promotor2 = widgets.Button(description="Consultar média promotor ", value='')
# Funcao que realiza a consulta
def on_button_clicked_query_c38(b):
        try:  
            # consulta
            query = f"select * from gasto_medio where promotor = '{promo_p38.value}'"
            # consulta do banco sendo colocada em df
            df = pd.read_sql_query(query, cnx)
            # limapando a saida
            output.clear_output()
            # display mostrando o campo de cidade, o botão da consulta, o resultado da consulta que está em df(em forma de tabeala), e o botão do menu
            display(promo_p38, button_consultar_promotor2, df,btn_nav_menu)  
            
            # caso a consulta acima não dê certo
        except:
            # limpa a saida
            output.clear_output() 
            # display mostra o campo de cidade, botão da consulta e o botao de menu
            display(user_u37, button_consultar_user, btn_nav_menu)
            # mensagem de alerta
            display("Não foi possível realizar a consulta.")

# função ".on_click" que diz ao botao qual funcao ele vai ativar quando for clicado
button_consultar_promotor2.on_click(on_button_clicked_query_c38)

# NAV CONSULTAR
# Parte de navegação

# Botao que aparece no menu. Se voce for na parte de menu 
# vai ver que ele está dentro de btn_nav_menu(pra quando menu for chamado ele estar visivel), 
# mas também está em dentro do display de "output" no final do codigo(para quando o codigo for iniciado pela primeira vez ele ficar visivel)
btn_nav_consultar_promotor2 = widgets.Button(description="3.8 consultar promotor ", value='')

# função que faz a troca do "menu" para dentro da pagina de "consultar eventos na cidade"
def on_button_clicked_consultar_promotor2(b):
    # limpando a saida
    output.clear_output()
    # mostrando o campo de cidade, o botao de consultar e menu
    display(promo_p38,button_consultar_promotor2, btn_nav_menu)

# "ao clicar no botao btn_nav_consultar_numero_eventos 
# realizar a funcao on_button_clicked_consultar_eventos_cidade
# que mostra a tela de consultar eventos pela cidade
btn_nav_consultar_promotor2.on_click(on_button_clicked_consultar_promotor)

# %%
# Quantas pessoas confirmaram a participação neste evento?
desc_d39= widgets.Text(
    value = '',
    description = 'nome do evento',
    disabled = False
)
# Botao que ativa a consulta no banco
button_consultar_confirmados = widgets.Button(description="Consultar confirmados ", value='')
# Funcao que realiza a consulta
def on_button_clicked_query_c39(b):
        try:  
            # consulta
            query = f"select * from nro_participantes_evento where descricao_evento = '{desc_d39.value}'"
            # consulta do banco sendo colocada em df
            df = pd.read_sql_query(query, cnx)
            # limapando a saida
            output.clear_output()
            # display mostrando o campo de cidade, o botão da consulta, o resultado da consulta que está em df(em forma de tabeala), e o botão do menu
            display(desc_d39, button_consultar_confirmados, df,btn_nav_menu)  
            
            # caso a consulta acima não dê certo
        except:
            # limpa a saida
            output.clear_output() 
            # display mostra o campo de cidade, botão da consulta e o botao de menu
            display(user_u37, button_consultar_user, btn_nav_menu)
            # mensagem de alerta
            display("Não foi possível realizar a consulta.")

# função ".on_click" que diz ao botao qual funcao ele vai ativar quando for clicado
button_consultar_confirmados.on_click(on_button_clicked_query_c39)

# NAV CONSULTAR
# Parte de navegação

# Botao que aparece no menu. Se voce for na parte de menu 
# vai ver que ele está dentro de btn_nav_menu(pra quando menu for chamado ele estar visivel), 
# mas também está em dentro do display de "output" no final do codigo(para quando o codigo for iniciado pela primeira vez ele ficar visivel)
btn_nav_consultar_confirmados = widgets.Button(description=" 3.9 participaçoes no evento ", value='')

# função que faz a troca do "menu" para dentro da pagina de "consultar eventos na cidade"
def on_button_clicked_consultar_confirmados(b):
    # limpando a saida
    output.clear_output()
    # mostrando o campo de cidade, o botao de consultar e menu
    display(desc_d39,button_consultar_confirmados, btn_nav_menu)

# "ao clicar no botao btn_nav_consultar_numero_eventos 
# realizar a funcao on_button_clicked_consultar_eventos_cidade
# que mostra a tela de consultar eventos pela cidade
btn_nav_consultar_confirmados.on_click(on_button_clicked_consultar_confirmados)

# %%
# Qual o número de homens e mulheres que confirmaram para esse evento? 
desc_d4= widgets.Text(
    value = '',
    description = 'nome do evento',
    disabled = False
)
# Botao que ativa a consulta no banco
button_consultar_genero = widgets.Button(description="3.10 genero por evento ", value='')
# Funcao que realiza a consulta
def on_button_clicked_query_c40(b):
        try:  
            # consulta
            query = f"select * from genero_evento where descricao_evento = '{desc_d4.value}'"
            # consulta do banco sendo colocada em df
            df = pd.read_sql_query(query, cnx)
            # limapando a saida
            output.clear_output()
            # display mostrando o campo de cidade, o botão da consulta, o resultado da consulta que está em df(em forma de tabeala), e o botão do menu
            display(desc_d4, button_consultar_genero, df,btn_nav_menu)  
            
            # caso a consulta acima não dê certo
        except:
            # limpa a saida
            output.clear_output() 
            # display mostra o campo de cidade, botão da consulta e o botao de menu
            display(user_u37, button_consultar_user, btn_nav_menu)
            # mensagem de alerta
            display("Não foi possível realizar a consulta.")

# função ".on_click" que diz ao botao qual funcao ele vai ativar quando for clicado
button_consultar_genero.on_click(on_button_clicked_query_c40)

# NAV CONSULTAR
# Parte de navegação

# Botao que aparece no menu. Se voce for na parte de menu 
# vai ver que ele está dentro de btn_nav_menu(pra quando menu for chamado ele estar visivel), 
# mas também está em dentro do display de "output" no final do codigo(para quando o codigo for iniciado pela primeira vez ele ficar visivel)
btn_nav_consultar_genero = widgets.Button(description=" 3.10 genero no evento ", value='')

# função que faz a troca do "menu" para dentro da pagina de "consultar eventos na cidade"
def on_button_clicked_consultar_genero(b):
    # limpando a saida
    output.clear_output()
    # mostrando o campo de cidade, o botao de consultar e menu
    display(desc_d4,button_consultar_genero, btn_nav_menu)

# "ao clicar no botao btn_nav_consultar_numero_eventos 
# realizar a funcao on_button_clicked_consultar_eventos_cidade
# que mostra a tela de consultar eventos pela cidade
btn_nav_consultar_genero.on_click(on_button_clicked_consultar_genero)

# %%
# Qual a descrição desta atividade? C3.4
atividade_a34= widgets.Text(
    value = '',
    description = 'nome da atividade:',
    disabled = False
)
cidade_c34= widgets.Text(
    value = '',
    description = 'nome da cidade:',
    disabled = False
)
# Botao que ativa a consulta no banco
button_consultar_desc_atividade = widgets.Button(description="Consultar orgs na minha cidade", value='')
# Funcao que realiza a consulta
def on_button_clicked_query_c34(b):
        try:  
            # consulta
            query = f"select * from descricao_evento where cidade_atv = '{cidade_c34.value}' and nome_atv = '{atividade_a34.value}'"
            # consulta do banco sendo colocada em df
            df = pd.read_sql_query(query, cnx)
            # limapando a saida
            output.clear_output()
            # display mostrando o campo de cidade, o botão da consulta, o resultado da consulta que está em df(em forma de tabeala), e o botão do menu
            display(atividade_a34, cidade_c34, button_consultar_desc_atividade, df,btn_nav_menu)  
            
            # caso a consulta acima não dê certo
        except:
            # limpa a saida
            output.clear_output() 
            # display mostra o campo de cidade, botão da consulta e o botao de menu
            display(cidade_c1, button_consultar_numero_eventos, btn_nav_menu)
            # mensagem de alerta
            display("Não foi possível realizar a consulta.")

# função ".on_click" que diz ao botao qual funcao ele vai ativar quando for clicado
button_consultar_desc_atividade.on_click(on_button_clicked_query_c3)

# NAV CONSULTAR
# Parte de navegação

# Botao que aparece no menu. Se voce for na parte de menu 
# vai ver que ele está dentro de btn_nav_menu(pra quando menu for chamado ele estar visivel), 
# mas também está em dentro do display de "output" no final do codigo(para quando o codigo for iniciado pela primeira vez ele ficar visivel)
btn_nav_consultar_desc_atividade = widgets.Button(description="3.4 descrição da atividade", value='')

# função que faz a troca do "menu" para dentro da pagina de "consultar eventos na cidade"
def on_button_clicked_consultar_desc_atividade(b):
    # limpando a saida
    output.clear_output()
    # mostrando o campo de cidade, o botao de consultar e menu
    display(cidade_c3,atividade_a34,button_consultar_numero_orgs_cidade, btn_nav_menu)

# "ao clicar no botao btn_nav_consultar_numero_eventos 
# realizar a funcao on_button_clicked_consultar_eventos_cidade
# que mostra a tela de consultar eventos pela cidade
btn_nav_consultar_desc_atividade.on_click(on_button_clicked_consultar_desc_atividade)

# %% [markdown]
# # Quantos eventos ocorrerão entre essas datas?

# %%
data1_c2 = widgets.DatePicker(
    description='Data 1:',
    disabled=False
)

data2_c2 = widgets.DatePicker(
    description='Data: 2',
    disabled=False
)

button_c2 = widgets.Button(description="Mostrar eventos entre datas", value='')
def on_button_clicked_query_c2(b):
        try:        
            query = f"select e.nome_evento, e.DATA_INICIO_EVENTO, p.nome_promotor from promotor p, evento e, ORGANIZA_EVENTO o where e.id_evento = o.ID_EVENTO_FK and p.ID_PROMOTOR = o.ID_PROMOTOR_FK and e.DATA_INICIO_EVENTO BETWEEN '{data1_c2.value}' and '{data2_c2.value}'"
            df = pd.read_sql_query(query, cnx)
            output.clear_output()
            display(data1_c2, data2_c2, button_c2, df,btn_nav_menu)   
        except:
            output.clear_output()  
            display(data1_c2, data2_c2, button_c2, btn_nav_menu)
            display("Não foi possível realizar a consulta.\n")
            
button_c2.on_click(on_button_clicked_query_c2)

#NAV CONSULTAR
btn_nav_c2 = widgets.Button(description="3.3  eventos entre datas", value='')
def on_button_clicked_c2(b):
    output.clear_output()
    display(data1_c2, data2_c2, button_c2, btn_nav_menu)

btn_nav_c2.on_click(on_button_clicked_c2)

# %% [markdown]
# # Menu

# %%
btn_nav_menu = widgets.Button(description="menu", value='')
def on_button_nav_menu(b):
    output.clear_output()
    display(btn_nav_crud_usuario, btn_nav_crud_promotor, btn_nav_crud_evento, btn_nav_crud_atividade, btn_nav_consultar_numero_eventos, btn_nav_c2, btn_nav_consultar_numero_orgs_cidade, btn_nav_consultar_desc_atividade, btn_nav_consultar_tipo_atividade, btn_nav_consultar_user_patro, btn_nav_consultar_user, btn_nav_consultar_promotor2, btn_nav_consultar_confirmados, btn_nav_consultar_genero)
    
btn_nav_menu.on_click(on_button_nav_menu)

# %%
output = widgets.Output()
with output:
       output.clear_output()
       display(btn_nav_crud_usuario, btn_nav_crud_promotor, btn_nav_crud_evento, btn_nav_crud_atividade, btn_nav_consultar_numero_eventos, btn_nav_c2, btn_nav_consultar_numero_orgs_cidade, btn_nav_consultar_desc_atividade, btn_nav_consultar_tipo_atividade, btn_nav_consultar_user_patro, btn_nav_consultar_user, btn_nav_consultar_promotor2, btn_nav_consultar_confirmados, btn_nav_consultar_genero)

# %%
output
# Out:
# Output()
